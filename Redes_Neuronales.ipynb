# %% [markdown]
# <a href="https://colab.research.google.com/github/yayaBD/machinelearning-az/blob/master/Redes_Neuronales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Creación data set

# %%
x,y=make_circles(n_samples=1000,factor=0.15, noise=0.15, random_state=42)
x1=x[:,0].flatten()
x2=x[:,1].flatten()

plt.scatter(x1,x2,c=y)
plt.show()

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
model=Sequential()
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x=x_train,
          y=y_train,
          batch_size=32,
          epochs=100,
          validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 9ms/step - loss: 0.6841 - accuracy: 0.4925 - val_loss: 0.6789 - val_accuracy: 0.5000
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6760 - accuracy: 0.4925 - val_loss: 0.6727 - val_accuracy: 0.5200
# Epoch 3/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6685 - accuracy: 0.5275 - val_loss: 0.6653 - val_accuracy: 0.5600
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6579 - accuracy: 0.5800 - val_loss: 0.6539 - val_accuracy: 0.6200
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6460 - accuracy: 0.6338 - val_loss: 0.6433 - val_accuracy: 0.6600
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6345 - accuracy: 0.6913 - val_loss: 0.6313 - val_accuracy: 0.7250
# Epoch 7/100
# ...

# %%
from IPython.core.pylabtools import figsize
plt.figure(figsize=(13,6))
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])

plt.title('Accuracy en train y test')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['training','testing'],loc='upper right')
plt.show()

# %%
from IPython.core.pylabtools import figsize
plt.figure(figsize=(13,6))
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])

plt.title('Loss en train y test')
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.legend(['training','testing'],loc='upper right')
plt.show()

# %%
model.evaluate(x_test, y_test)
model.predict(x_test)
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3103 - accuracy: 0.8800
# array([[1.96327537e-01],
#        [7.91188955e-01],
#        [6.87767982e-01],
#        [8.33866000e-03],
#        [9.90774393e-01],
#        [2.07420707e-01],
#        [3.15999985e-02],
#        [1.73151493e-03],
#        [9.95620847e-01],
#        [8.70096445e-01],
#        [4.56172526e-02],
#        [4.23390508e-01],
#        [5.91754913e-02],
#        [9.96198416e-01],
#        [9.70962405e-01],
#        [9.79892731e-01],
#        [5.26960194e-02],
#        [2.15973169e-01],
#        [8.57187510e-01],
#        [1.72879100e-02],
#        [9.94976878e-01],
#        [9.26787257e-01],
#        [9.08926129e-03],
#        [6.89811409e-02],
#        [9.84555483e-01],
#        [4.43774343e-01],
#        [9.94342029e-01],
#        [9.62048054e-01],
#        [9.12419796e-01],
#        [9.16006267e-02],
#        [2.78641164e-01],
#        [9.63438272e-01],
#        [2.45370865e-02],
# ...
